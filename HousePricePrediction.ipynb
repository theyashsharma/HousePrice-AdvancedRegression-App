# %%
import pandas as pd 
import numpy as np
# Out:
# C:\Users\yasha\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\yasha\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\yasha\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train = train.dropna(how = "any", thresh=800, axis = 1)
test = test.dropna(how = "any", thresh=800, axis = 1)

# %%
train.shape
# Out:
# (1460, 76)

# %%
test.shape
# Out:
# (1459, 75)

# %%
#pd.set_option("display.max_rows", None)
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 76, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', verbose=0)
imputer = imputer.fit(train[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'  ]])
train[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'  ]] = imputer.transform(train[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'  ]])

imputer2 = SimpleImputer(missing_values=np.nan, strategy='mean', verbose=0)
imputer2 = imputer2.fit(test[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']])
test[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']] = imputer2.transform(test[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']])
# Out:
# <ipython-input-9-5ae9179e66f8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
# C:\Users\yasha\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# <ipython-input-9-5ae9179e66f8>:20: SettingWithCopyWarning:
# ...

# %%
train.shape
# Out:
# (1460, 76)

# %%
train.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
X_train = train.iloc[:, 1:-1]
y_train = train.iloc[:, -1].values
X_test = test.iloc[:, 1:]

# %%
type(y_train)
# Out:
# numpy.ndarray

# %% [markdown]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# ct = ColumnTransformer([('encoder', OneHotEncoder(), ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
# 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
# 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
# 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'])], remainder = 'passthrough')
# X_train = np.array(ct.fit_transform(X_train))
#
# ct2 = ColumnTransformer([('encoder', OneHotEncoder(), ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
# 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
# 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
# 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'])], remainder = 'passthrough')
# X_test = np.array(ct2.fit_transform(X_test))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_train['MSZoning'] = le.fit_transform(X_train['MSZoning'].astype(str))
X_train['Street'] = le.fit_transform(X_train['Street'].astype(str))
X_train['LotShape'] = le.fit_transform(X_train['LotShape'].astype(str))
X_train['LandContour'] = le.fit_transform(X_train['LandContour'].astype(str))
X_train['Utilities'] = le.fit_transform(X_train['Utilities'].astype(str))
X_train['LotConfig'] = le.fit_transform(X_train['LotConfig'].astype(str))
X_train['LandSlope'] = le.fit_transform(X_train['LandSlope'].astype(str))
X_train['Neighborhood'] = le.fit_transform(X_train['Neighborhood'].astype(str))
X_train['Condition1'] = le.fit_transform(X_train['Condition1'].astype(str))
X_train['Condition2'] = le.fit_transform(X_train['Condition2'].astype(str))
X_train['BldgType'] = le.fit_transform(X_train['BldgType'].astype(str))
X_train['HouseStyle'] = le.fit_transform(X_train['HouseStyle'].astype(str))
X_train['Exterior1st'] = le.fit_transform(X_train['Exterior1st'].astype(str))
X_train['Exterior2nd'] = le.fit_transform(X_train['Exterior2nd'].astype(str))
X_train['MasVnrType'] = le.fit_transform(X_train['MasVnrType'].astype(str))
X_train['ExterQual'] = le.fit_transform(X_train['ExterQual'].astype(str))
X_train['RoofStyle'] = le.fit_transform(X_train['RoofStyle'].astype(str))
X_train['ExterCond'] = le.fit_transform(X_train['ExterCond'].astype(str))
X_train['Foundation'] = le.fit_transform(X_train['Foundation'].astype(str))
X_train['BsmtQual'] = le.fit_transform(X_train['BsmtQual'].astype(str))
X_train['BsmtCond'] = le.fit_transform(X_train['BsmtCond'].astype(str))
X_train['BsmtExposure'] = le.fit_transform(X_train['BsmtExposure'].astype(str))
X_train['BsmtFinType1'] = le.fit_transform(X_train['BsmtFinType1'].astype(str))
X_train['BsmtFinType2'] = le.fit_transform(X_train['BsmtFinType2'].astype(str))
X_train['Heating'] = le.fit_transform(X_train['Heating'].astype(str))
X_train['HeatingQC'] = le.fit_transform(X_train['HeatingQC'].astype(str))
X_train['CentralAir'] = le.fit_transform(X_train['CentralAir'].astype(str))
X_train['Electrical'] = le.fit_transform(X_train['Electrical'].astype(str))
X_train['KitchenQual'] = le.fit_transform(X_train['KitchenQual'].astype(str))
X_train['Functional'] = le.fit_transform(X_train['Functional'].astype(str))
X_train['GarageType'] = le.fit_transform(X_train['GarageType'].astype(str))
X_train['GarageYrBlt'] = le.fit_transform(X_train['GarageYrBlt'].astype(str))
X_train['GarageFinish'] = le.fit_transform(X_train['GarageFinish'].astype(str))
X_train['GarageQual'] = le.fit_transform(X_train['GarageQual'].astype(str))
X_train['GarageCond'] = le.fit_transform(X_train['GarageCond'].astype(str))
X_train['PavedDrive'] = le.fit_transform(X_train['PavedDrive'].astype(str))
X_train['SaleType'] = le.fit_transform(X_train['SaleType'].astype(str))
X_train['SaleCondition'] = le.fit_transform(X_train['SaleCondition'].astype(str))
X_train['RoofMatl'] = le.fit_transform(X_train['RoofMatl'].astype(str))
X_test['MSZoning'] = le.fit_transform(X_test['MSZoning'].astype(str))
X_test['Street'] = le.fit_transform(X_test['Street'].astype(str))
X_test['LotShape'] = le.fit_transform(X_test['LotShape'].astype(str))
X_test['LandContour'] = le.fit_transform(X_test['LandContour'].astype(str))
X_test['Utilities'] = le.fit_transform(X_test['Utilities'].astype(str))
X_test['LotConfig'] = le.fit_transform(X_test['LotConfig'].astype(str))
X_test['LandSlope'] = le.fit_transform(X_test['LandSlope'].astype(str))
X_test['Neighborhood'] = le.fit_transform(X_test['Neighborhood'].astype(str))
X_test['Condition1'] = le.fit_transform(X_test['Condition1'].astype(str))
X_test['Condition2'] = le.fit_transform(X_test['Condition2'].astype(str))
X_test['BldgType'] = le.fit_transform(X_test['BldgType'].astype(str))
X_test['HouseStyle'] = le.fit_transform(X_test['HouseStyle'].astype(str))
X_test['Exterior1st'] = le.fit_transform(X_test['Exterior1st'].astype(str))
X_test['Exterior2nd'] = le.fit_transform(X_test['Exterior2nd'].astype(str))
X_test['MasVnrType'] = le.fit_transform(X_test['MasVnrType'].astype(str))
X_test['ExterQual'] = le.fit_transform(X_test['ExterQual'].astype(str))
X_test['RoofStyle'] = le.fit_transform(X_test['RoofStyle'].astype(str))
X_test['ExterCond'] = le.fit_transform(X_test['ExterCond'].astype(str))
X_test['Foundation'] = le.fit_transform(X_test['Foundation'].astype(str))
X_test['BsmtQual'] = le.fit_transform(X_test['BsmtQual'].astype(str))
X_test['BsmtCond'] = le.fit_transform(X_test['BsmtCond'].astype(str))
X_test['BsmtExposure'] = le.fit_transform(X_test['BsmtExposure'].astype(str))
X_test['BsmtFinType1'] = le.fit_transform(X_test['BsmtFinType1'].astype(str))
X_test['BsmtFinType2'] = le.fit_transform(X_test['BsmtFinType2'].astype(str))
X_test['Heating'] = le.fit_transform(X_test['Heating'].astype(str))
X_test['HeatingQC'] = le.fit_transform(X_test['HeatingQC'].astype(str))
X_test['CentralAir'] = le.fit_transform(X_test['CentralAir'].astype(str))
X_test['Electrical'] = le.fit_transform(X_test['Electrical'].astype(str))
X_test['KitchenQual'] = le.fit_transform(X_test['KitchenQual'].astype(str))
X_test['Functional'] = le.fit_transform(X_test['Functional'].astype(str))
X_test['GarageType'] = le.fit_transform(X_test['GarageType'].astype(str))
X_test['GarageYrBlt'] = le.fit_transform(X_test['GarageYrBlt'].astype(str))
X_test['GarageFinish'] = le.fit_transform(X_test['GarageFinish'].astype(str))
X_test['GarageQual'] = le.fit_transform(X_test['GarageQual'].astype(str))
X_test['GarageCond'] = le.fit_transform(X_test['GarageCond'].astype(str))
X_test['PavedDrive'] = le.fit_transform(X_test['PavedDrive'].astype(str))
X_test['SaleType'] = le.fit_transform(X_test['SaleType'].astype(str))
X_test['SaleCondition'] = le.fit_transform(X_test['SaleCondition'].astype(str))
X_test['RoofMatl'] = le.fit_transform(X_test['RoofMatl'].astype(str))

# %%
X_train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0           60.0         3         65.0   8450.0       1         3
# 1           20.0         3         80.0   9600.0       1         3
# 2           60.0         3         68.0  11250.0       1         0
# 3           70.0         3         60.0   9550.0       1         0
# 4           60.0         3         84.0  14260.0       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455        60.0         3         62.0   7917.0       1         3
# 1456        20.0         3         85.0  13175.0       1         3
# 1457        70.0         3         66.0   9042.0       1         3
# 1458        20.0         3         68.0   9717.0       1         3
# 1459        20.0         3         75.0   9937.0       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0               3          0          4          0  ...         61.0
# ...

# %%
X_test
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0           20.0         2         80.0  11622.0       1         3
# 1           20.0         3         81.0  14267.0       1         0
# 2           60.0         3         74.0  13830.0       1         0
# 3           60.0         3         78.0   9978.0       1         0
# 4          120.0         3         43.0   5005.0       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1454       160.0         4         21.0   1936.0       1         3
# 1455       160.0         4         21.0   1894.0       1         3
# 1456        20.0         3        160.0  20000.0       1         3
# 1457        85.0         3         62.0  10441.0       1         3
# 1458        60.0         3         74.0   9627.0       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0               3          0          4          0  ...          0.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train.iloc[:, :] = sc.fit_transform(X_train.iloc[:, :])
X_test.iloc[:, :] = sc.transform(X_test.iloc[:, :])

# %%
X_train = X_train.values

# %%
X_train
# Out:
# array([[ 0.07337496, -0.04553194, -0.22937175, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        [-0.87256276, -0.04553194,  0.4519361 , ..., -0.61443862,
#          0.31386709,  0.2085023 ],
#        [ 0.07337496, -0.04553194, -0.09311018, ...,  0.13877749,
#          0.31386709,  0.2085023 ],
#        ...,
#        [ 0.30985939, -0.04553194, -0.18395123, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [-0.87256276, -0.04553194, -0.09311018, ...,  1.64520971,
#          0.31386709,  0.2085023 ],
#        [-0.87256276, -0.04553194,  0.22483348, ...,  0.13877749,
#          0.31386709,  0.2085023 ]])

# %%
X_test = X_test.values

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=250, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=250, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([125803.95041234, 155263.8488316 , 182365.20188623, ...,
#        153127.96331944, 119107.61695222, 226349.67372071])

# %%
op = list(zip(test.iloc[:, 0].astype(int),y_pred.astype(float)))

# %%
op_df = pd.DataFrame(op, columns = ['Id', 'SalePrice'])

# %%
op_df
# Out:
#         Id      SalePrice
# 0     1461  125803.950412
# 1     1462  155263.848832
# 2     1463  182365.201886
# 3     1464  180699.211413
# 4     1465  199285.076195
# ...    ...            ...
# 1454  2915   86454.401402
# 1455  2916   87462.536261
# 1456  2917  153127.963319
# 1457  2918  119107.616952
# 1458  2919  226349.673721
#
# [1459 rows x 2 columns]

# %%
op_df.to_csv('op_file16.csv', index = False)
